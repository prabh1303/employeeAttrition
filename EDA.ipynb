# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,OneHotEncoder,LabelEncoder
from sklearn.svm import SVR
import seaborn as sns

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
#check unique values in the column
print(df.apply(lambda col: col.unique().sum()))
# Out:
# Age                                                                      1677
# Attrition                                                               YesNo
# BusinessTravel                       Travel_RarelyTravel_FrequentlyNon-Travel
# DailyRate                                                              710161
# Department                         SalesResearch & DevelopmentHuman Resources
# DistanceFromHome                                                          435
# Education                                                                  15
# EducationField              Life SciencesOtherMedicalMarketingTechnical De...
# EmployeeCount                                                               1
# EmployeeNumber                                                        1506552
# EnvironmentSatisfaction                                                    10
# Gender                                                             FemaleMale
# HourlyRate                                                               4615
# JobInvolvement                                                             10
# JobLevel                                                                   15
# JobRole                     Sales ExecutiveResearch ScientistLaboratory Te...
# JobSatisfaction                                                            10
# MaritalStatus                                           SingleMarriedDivorced
# MonthlyIncome                                                         9057813
# MonthlyRate                                                          20517681
# NumCompaniesWorked                                                         45
# Over18                                                                      Y
# OverTime                                                                YesNo
# PercentSalaryHike                                                         270
# PerformanceRating                                                           7
# RelationshipSatisfaction                                                   10
# StandardHours                                                              80
# StockOptionLevel                                                            6
# TotalWorkingYears                                                         781
# TrainingTimesLastYear                                                      21
# WorkLifeBalance                                                            10
# YearsAtCompany                                                            680
# YearsInCurrentRole                                                        171
# YearsSinceLastPromotion                                                   120
# YearsWithCurrManager                                                      153
# dtype: object

# %%
cat_df=df.select_dtypes(include='object')

for i in cat_df:
    plt.figure(figsize=(15, 15))
    sns.catplot(data=df,x=i,kind='count')

# %%
for col in df:
    print(df[df['Attrition']=='Yes'][col])
# Out:
# 0       41
# 2       37
# 14      28
# 21      36
# 24      34
#         ..
# 1438    23
# 1442    29
# 1444    56
# 1452    50
# 1461    50
# Name: Age, Length: 237, dtype: int64
# 0       Yes
# 2       Yes
# 14      Yes
# 21      Yes
# 24      Yes
#        ...
# 1438    Yes
# 1442    Yes
# 1444    Yes
# 1452    Yes
# 1461    Yes
# Name: Attrition, Length: 237, dtype: object
# 0           Travel_Rarely
# 2           Travel_Rarely
# 14          Travel_Rarely
# 21          Travel_Rarely
# 24          Travel_Rarely
#               ...
# 1438    Travel_Frequently
# 1442        Travel_Rarely
# 1444        Travel_Rarely
# 1452    Travel_Frequently
# 1461        Travel_Rarely
# Name: BusinessTravel, Length: 237, dtype: object
# 0       1102
# 2       1373
# 14       103
# 21      1218
# 24       699
#         ...
# 1438     638
# 1442    1092
# 1444     310
# 1452     878
# 1461     410
# Name: DailyRate, Length: 237, dtype: int64
# 0                        Sales
# 2       Research & Development
# 14      Research & Development
# 21                       Sales
# 24      Research & Development
#                  ...
# 1438                     Sales
# 1442    Research & Development
# 1444    Research & Development
# 1452                     Sales
# 1461                     Sales
# Name: Department, Length: 237, dtype: object
# 0        1
# 2        2
# 14      24
# 21       9
# 24       6
#         ..
# 1438     9
# 1442     1
# 1444     7
# 1452     1
# 1461    28
# Name: DistanceFromHome, Length: 237, dtype: int64
# 0       2
# 2       2
# 14      3
# 21      4
# 24      1
#        ..
# 1438    3
# 1442    4
# 1444    2
# 1452    4
# 1461    3
# Name: Education, Length: 237, dtype: int64
# 0          Life Sciences
# 2                  Other
# 14         Life Sciences
# 21         Life Sciences
# 24               Medical
#               ...
# 1438           Marketing
# 1442             Medical
# 1444    Technical Degree
# 1452       Life Sciences
# 1461           Marketing
# Name: EducationField, Length: 237, dtype: object
# 0       1
# 2       1
# 14      1
# 21      1
# 24      1
#        ..
# 1438    1
# 1442    1
# 1444    1
# 1452    1
# 1461    1
# Name: EmployeeCount, Length: 237, dtype: int64
# 0          1
# 2          4
# 14        19
# 21        27
# 24        31
#         ...
# 1438    2023
# 1442    2027
# 1444    2032
# 1452    2044
# 1461    2055
# Name: EmployeeNumber, Length: 237, dtype: int64
# 0       2
# 2       4
# 14      3
# 21      3
# 24      2
#        ..
# 1438    4
# 1442    1
# 1444    4
# 1452    2
# 1461    4
# Name: EnvironmentSatisfaction, Length: 237, dtype: int64
# 0       Female
# 2         Male
# 14        Male
# 21        Male
# 24        Male
#          ...
# 1438      Male
# 1442      Male
# 1444      Male
# 1452      Male
# 1461      Male
# Name: Gender, Length: 237, dtype: object
# 0       94
# 2       92
# 14      50
# 21      82
# 24      83
#         ..
# 1438    33
# 1442    36
# 1444    72
# 1452    94
# 1461    39
# Name: HourlyRate, Length: 237, dtype: int64
# 0       3
# 2       2
# 14      2
# 21      2
# 24      3
#        ..
# 1438    3
# 1442    3
# 1444    3
# 1452    3
# 1461    2
# Name: JobInvolvement, Length: 237, dtype: int64
# 0       2
# 2       1
# 14      1
# 21      1
# 24      1
#        ..
# 1438    1
# 1442    1
# 1444    1
# 1452    2
# 1461    3
# Name: JobLevel, Length: 237, dtype: int64
# 0             Sales Executive
# 2       Laboratory Technician
# 14      Laboratory Technician
# 21       Sales Representative
# 24         Research Scientist
#                 ...
# 1438     Sales Representative
# 1442       Research Scientist
# 1444    Laboratory Technician
# 1452          Sales Executive
# 1461          Sales Executive
# Name: JobRole, Length: 237, dtype: object
# 0       4
# 2       3
# 14      3
# 21      1
# 24      1
#        ..
# 1438    1
# 1442    4
# 1444    3
# 1452    3
# 1461    1
# Name: JobSatisfaction, Length: 237, dtype: int64
# 0         Single
# 2         Single
# 14        Single
# 21        Single
# 24        Single
#           ...
# 1438     Married
# 1442     Married
# 1444     Married
# 1452    Divorced
# 1461    Divorced
# Name: MaritalStatus, Length: 237, dtype: object
# 0        5993
# 2        2090
# 14       2028
# 21       3407
# 24       2960
#         ...
# 1438     1790
# 1442     4787
# 1444     2339
# 1452     6728
# 1461    10854
# Name: MonthlyIncome, Length: 237, dtype: int64
# 0       19479
# 2        2396
# 14      12947
# 21       6986
# 24      17102
#         ...
# 1438    26956
# 1442    26124
# 1444     3666
# 1452    14255
# 1461    16586
# Name: MonthlyRate, Length: 237, dtype: int64
# 0       8
# 2       6
# 14      5
# 21      7
# 24      2
#        ..
# 1438    1
# 1442    9
# 1444    8
# 1452    7
# 1461    4
# Name: NumCompaniesWorked, Length: 237, dtype: int64
# 0       Y
# 2       Y
# 14      Y
# 21      Y
# 24      Y
#        ..
# 1438    Y
# 1442    Y
# 1444    Y
# 1452    Y
# 1461    Y
# Name: Over18, Length: 237, dtype: object
# 0       Yes
# 2       Yes
# 14      Yes
# 21       No
# 24       No
#        ...
# 1438     No
# 1442    Yes
# 1444     No
# 1452     No
# 1461    Yes
# Name: OverTime, Length: 237, dtype: object
# 0       11
# 2       15
# 14      14
# 21      23
# 24      11
#         ..
# 1438    19
# 1442    14
# 1444    11
# 1452    12
# 1461    13
# Name: PercentSalaryHike, Length: 237, dtype: int64
# 0       3
# 2       3
# 14      3
# 21      4
# 24      3
#        ..
# 1438    3
# 1442    3
# 1444    3
# 1452    3
# 1461    3
# Name: PerformanceRating, Length: 237, dtype: int64
# 0       1
# 2       2
# 14      2
# 21      2
# 24      3
#        ..
# 1438    1
# 1442    2
# 1444    4
# 1452    4
# 1461    2
# Name: RelationshipSatisfaction, Length: 237, dtype: int64
# 0       80
# 2       80
# 14      80
# 21      80
# 24      80
#         ..
# 1438    80
# 1442    80
# 1444    80
# 1452    80
# 1461    80
# Name: StandardHours, Length: 237, dtype: int64
# 0       0
# 2       0
# 14      0
# 21      0
# 24      0
#        ..
# 1438    1
# 1442    3
# 1444    1
# 1452    2
# 1461    1
# Name: StockOptionLevel, Length: 237, dtype: int64
# 0        8
# 2        7
# 14       6
# 21      10
# 24       8
#         ..
# 1438     1
# 1442     4
# 1444    14
# 1452    12
# 1461    20
# Name: TotalWorkingYears, Length: 237, dtype: int64
# 0       0
# 2       3
# 14      4
# 21      4
# 24      2
#        ..
# 1438    3
# 1442    3
# 1444    4
# 1452    3
# 1461    3
# Name: TrainingTimesLastYear, Length: 237, dtype: int64
# 0       1
# 2       3
# 14      3
# 21      3
# 24      3
#        ..
# 1438    2
# 1442    4
# 1444    1
# 1452    3
# 1461    3
# Name: WorkLifeBalance, Length: 237, dtype: int64
# 0        6
# 2        0
# 14       4
# 21       5
# 24       4
#         ..
# 1438     1
# 1442     2
# 1444    10
# 1452     6
# 1461     3
# Name: YearsAtCompany, Length: 237, dtype: int64
# 0       4
# 2       0
# 14      2
# 21      3
# 24      2
#        ..
# 1438    0
# 1442    2
# 1444    9
# 1452    3
# 1461    2
# Name: YearsInCurrentRole, Length: 237, dtype: int64
# 0       0
# 2       0
# 14      0
# 21      0
# 24      1
#        ..
# 1438    1
# 1442    2
# 1444    9
# 1452    0
# 1461    2
# Name: YearsSinceLastPromotion, Length: 237, dtype: int64
# 0       5
# 2       0
# 14      3
# 21      3
# 24      3
#        ..
# 1438    0
# 1442    2
# 1444    8
# 1452    1
# 1461    0
# Name: YearsWithCurrManager, Length: 237, dtype: int64

# %%
#plot distributions
k=1
plt.figure(figsize=(40, 40))
for col in df:
  if col=="Attrition":
    continue
  yes = df[df['Attrition'] == 'Yes'][col]
  no = df[df['Attrition'] == 'No'][col]
  plt.subplot(6, 6, k)
  plt.hist(yes, bins=25, alpha=0.5, label='yes', color='b')
  plt.hist(no, bins=25, alpha=0.5, label='no', color='r')
  plt.legend(loc='upper right')
  plt.title(col)
  k+=1

# %%
sns.catplot(data=df,x="Attrition",kind='count')

# %%
# colors = sns.color_palette("husl", 2)
plt.pie(df['Attrition'].value_counts(),labels=['No','Yes'],autopct='%.2f%%')
plt.show()

# %%
table=pd.crosstab(df.JobSatisfaction, df.Attrition)
table
# Out:
# Attrition         No  Yes
# JobSatisfaction
# 1                223   66
# 2                234   46
# 3                369   73
# 4                407   52

# %%
table=pd.crosstab(df.JobSatisfaction, df.Attrition)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar')
plt.title('Stacked Bar Chart of Job satisfaction vs attrition')
# Out:
# Text(0.5, 1.0, 'Stacked Bar Chart of Job satisfaction vs attrition')

# %%
table=pd.crosstab(df.OverTime, df.Attrition)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar')
plt.title('Stacked Bar Chart of Overtime vs attrition')
# Out:
# Text(0.5, 1.0, 'Stacked Bar Chart of Overtime vs attrition')

# %%
table=pd.crosstab(df.BusinessTravel, df.Attrition)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar')
plt.title('Stacked Bar Chart of Business Travel vs attrition')
# Out:
# Text(0.5, 1.0, 'Stacked Bar Chart of Business Travel vs attrition')

# %%
table=pd.crosstab(df.YearsSinceLastPromotion, df.Attrition)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar')
plt.title('Stacked Bar Chart of Years since last promotion vs attrition')
# Out:
# Text(0.5, 1.0, 'Stacked Bar Chart of Years since last promotion vs attrition')

# %%
f,ax=plt.subplots(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,linewidth=.5,fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
a4_dims = (25, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(data=df,x="JobRole",hue="Attrition", ax=ax )
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>
